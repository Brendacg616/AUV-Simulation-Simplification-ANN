# %%
# Load thrust scalers
import joblib
scaler_thrust_in = joblib.load("./Thrust/scaler_thrust_in.pkl")
scaler_thrust_out = joblib.load("./Thrust/scaler_thrust_out.pkl")

# Print scaler details
print("Thrust Input Scaler Details:")
print(f"  Mean: {scaler_thrust_in.mean_}")
print(f"  Scale: {scaler_thrust_in.scale_}")
print("\nThrust Output Scaler Details:")
print(f"  Mean: {scaler_thrust_out.mean_}")
print(f"  Scale: {scaler_thrust_out.scale_}")
# Out:
# Thrust Input Scaler Details:
#   Mean: [ 9.36830800e-02 -3.56945384e-04 -3.00467760e-03 -3.56807775e-03
#   4.82418792e-03 -1.25281492e-04  4.69829390e-01 -6.54898748e-03
#  -5.00000000e+00  1.06587922e-03 -1.00415536e-03 -1.10464251e-03
#  -5.24658402e-04  5.07178617e-02 -5.24658402e-04 -6.80717325e-02]
#   Scale: [2.92657016e-02 2.00274623e-02 3.86484392e-03 1.85571661e-01
#  7.61794197e-03 4.93684150e-02 2.58530178e-01 1.81472534e-01
#  1.00000000e+00 1.62697331e-01 4.19569711e-03 2.27921719e-01
#  1.62912746e-01 9.36273048e+00 1.62912746e-01 3.41780388e+01]
#
# Thrust Output Scaler Details:
#   Mean: [ 0.23719756 -0.20298342 -0.00752556  0.01185614  0.00236131 -0.00421431
#   0.00378341]
#   Scale: [0.84467516 0.14467264 0.95868627 0.57992117 0.12428325 0.53686431
#  0.50158498]
