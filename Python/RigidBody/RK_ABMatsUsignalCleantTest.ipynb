# %%
import nn_fncs
import numpy as np

trajectory_samples = 400

def create_dataset_from_mat(file_path, list_of_vars):
    ws_files = nn_fncs.find_mat_files(file_path, recursive=True)
    input = np.zeros((trajectory_samples, 25))    
    for f in ws_files:
        print(f)
        mat_data = nn_fncs.read_mat_workspace(f)
        # N = mat_data.get('N')
        N = 2000
        if N is None:
            continue
        data = np.zeros((int(N), 1))
        skip = False
        for var in list_of_vars:
            temp_data = mat_data.get(var)
            if temp_data is not None:
                if np.isnan(temp_data).any():
                    skip = True
                    print(f"Skipping {f} due to NaN values in {var}")
                    break
                print(f"{var} found with shape {temp_data.shape}")
                data = np.hstack((data, temp_data))
            else:
                print(f"{var} not found in {f}, skipping this file.")
                skip = True
                break
        if skip: 
            continue
        data = data[::5, 1:]  # Remove the initial zero column
        input = np.dstack((input, data))

    print(input.shape)
    return input[1:]

# %%
data_labels = ['xout','Tail_Forces_out', 'Moments_Add_out']
data = create_dataset_from_mat('./Data', data_labels)
print(data.shape)
x_data = data[:, :12, :]
u_data = data[:, 12:, :]
# Out:
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_10.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_100.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1000.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1001.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1002.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1003.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1004.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1005.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1006.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1007.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1008.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1009.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_101.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1010.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1011.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1012.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1013.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1014.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1015.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1016.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1017.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1018.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1019.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_102.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1020.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1021.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1022.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1023.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1024.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1025.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1026.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1027.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1028.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1029.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_103.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1030.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1031.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1032.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1033.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1034.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1035.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1036.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1037.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1038.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1039.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_104.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1040.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1041.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1042.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1043.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1044.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1045.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1046.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1047.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1048.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1049.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_105.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1050.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1051.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1052.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1053.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1054.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1055.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1056.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1057.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1058.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1059.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_106.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1060.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1061.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1062.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1063.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1064.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1065.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1066.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1067.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1068.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1069.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_107.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1070.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1071.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1072.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1073.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1074.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1075.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1076.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1077.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1078.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1079.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_108.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1080.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1081.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1082.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1083.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1084.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1085.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1086.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1087.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1088.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1089.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_109.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1090.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1091.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1092.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1093.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1094.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1095.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1096.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1097.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1098.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1099.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_11.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_110.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1100.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1101.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1102.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1103.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1104.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1105.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1106.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1107.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1108.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1109.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_111.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1110.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1111.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1112.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1113.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1114.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1115.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1116.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1117.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1118.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1119.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_112.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1120.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1121.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1122.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1123.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1124.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1125.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1126.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1127.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1128.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1129.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_113.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1130.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1131.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1132.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1133.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1134.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1135.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1136.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1137.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1138.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1139.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_114.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1140.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1141.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1142.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1143.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1144.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1145.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1146.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1147.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1148.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1149.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_115.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1150.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1151.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1152.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1153.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1154.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1155.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1156.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1157.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1158.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_1159.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# ...
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_946.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_947.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_948.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_949.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_95.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_950.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_951.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_952.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_953.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_954.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_955.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_956.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_957.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_958.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_959.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_96.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_960.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_961.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_962.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_963.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_964.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_965.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_966.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_967.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_968.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_969.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_97.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_970.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_971.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_972.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_973.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_974.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_975.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_976.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_977.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_978.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_979.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_98.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_980.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_981.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_982.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_983.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_984.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_985.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_986.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_987.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_988.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_989.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_99.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_990.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_991.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_992.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_993.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_994.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_995.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_996.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_997.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_998.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# C:\Users\brend\OneDrive - University of Glasgow\Dissertation\Main Fish Original\Main Fish Original\PyTorch_NN\RigidBody\Data\RigidBodyData_999.mat
# xout found with shape (2000, 12)
# Tail_Forces_out found with shape (2000, 12)
# Moments_Add_out found with shape (2000, 1)
# (400, 25, 3989)
# (399, 25, 3989)

# %%
print(x_data.shape)
print(u_data.shape)
u_data = u_data[:, ~np.all(u_data == 0, axis=(0, 2)), :]
print(u_data.shape)
# Out:
# (399, 12, 3989)
# (399, 13, 3989)
# (399, 8, 3989)

# %%
# Randomly shuffle and split the dataset into training and testing sets
# Use a seed for reproducibility
np.random.seed(42)
num_trajectories = x_data.shape[2]
indices = np.random.permutation(num_trajectories)

x_data = x_data[:, :, indices]
u_data = u_data[:, :, indices]

# %%
import torch
from torch.utils.data import DataLoader
torch.set_default_dtype(torch.float32)

# Split data into training and validation sets
x_train_dataset = x_data[:,:,:-2]
x_valid_dataset = x_data[:,:,-2]
x_test_dataset = x_data[:,:,-1]

u_train_dataset = u_data[:,:,:-2]
u_valid_dataset = u_data[:,:,-2]
u_test_dataset = u_data[:,:,-1]

print('Train, Valid, Test dataset shapes:')
print(x_train_dataset.shape, x_valid_dataset.shape, x_test_dataset.shape)
print('Data Types:')
print(x_train_dataset.dtype, x_valid_dataset.dtype, x_test_dataset.dtype)
# Out:
# Train, Valid, Test dataset shapes:
# (399, 12, 3987) (399, 12) (399, 12)
# Data Types:
# float64 float64 float64

# %%
# # Standardize the data

import torch
from sklearn.preprocessing import StandardScaler
x_scaler = StandardScaler()
u_scaler = StandardScaler()

x_train_dataset = x_scaler.fit_transform(x_train_dataset.reshape(-1, x_train_dataset.shape[1])).reshape(x_train_dataset.shape)
u_train_dataset = u_scaler.fit_transform(u_train_dataset.reshape(-1, u_train_dataset.shape[1])).reshape(u_train_dataset.shape)

x_valid_dataset = x_scaler.transform(x_valid_dataset)
u_valid_dataset = u_scaler.transform(u_valid_dataset)

x_test_dataset = x_scaler.transform(x_test_dataset)
u_test_dataset = u_scaler.transform(u_test_dataset)

# %%
# Create test tensors
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
x_test_tensor = torch.tensor(x_test_dataset, dtype=torch.float32).to(device)
u_test_tensor = torch.tensor(u_test_dataset, dtype=torch.float32).to(device)

# %%
# Save scalers
import joblib
joblib.dump(x_scaler, 'x_scaler_clean.save')
joblib.dump(u_scaler, 'u_scaler_clean.save')
# Out:
# ['u_scaler_clean.save']

# %%
# MODEL STRUCTURE

import torch
import torch.nn as nn
import torch.nn.functional as F
n_neurons = 64
dropout_rate = 0.1
class RigidBodyNN(nn.Module):
    def __init__(self, u_size=1, x_size=3, n_neurons=64):  
        super(RigidBodyNN, self).__init__()
        # Fully connected layers
        self.A1 = nn.Linear(x_size, n_neurons) 
        self.A2 = nn.Linear(n_neurons, n_neurons)
        self.A3 = nn.Linear(n_neurons, n_neurons)
        self.A4 = nn.Linear(n_neurons, n_neurons)
        self.outputA = nn.Linear(n_neurons, x_size)

        self.B1 = nn.Linear(u_size, n_neurons) 
        self.B2 = nn.Linear(n_neurons, n_neurons)
        self.outputB = nn.Linear(n_neurons, x_size)
        
        self.dropout = nn.Dropout(dropout_rate)
        

    def forward(self, x0, u):
        
        outA = F.softplus(self.A1(x0))
        outA = self.dropout(F.softplus(self.A2(outA)))
        outA = self.dropout(F.softplus(self.A3(outA)))
        outA = self.dropout(F.softplus(self.A4(outA)))
        outA = self.outputA(outA)

        outB = F.softplus(self.B1(u))
        outB = self.dropout(F.softplus(self.B2(outB)))
        outB = self.outputB(outB)

        x = outA + outB  
        return x

# Create the model
model = RigidBodyNN(u_size=u_train_dataset.shape[1], x_size=x_train_dataset.shape[1])

# Print model summary
print(model)
print(f'Total parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}')
# Out:
# RigidBodyNN(
#   (A1): Linear(in_features=12, out_features=64, bias=True)
#   (A2): Linear(in_features=64, out_features=64, bias=True)
#   (A3): Linear(in_features=64, out_features=64, bias=True)
#   (A4): Linear(in_features=64, out_features=64, bias=True)
#   (outputA): Linear(in_features=64, out_features=12, bias=True)
#   (B1): Linear(in_features=8, out_features=64, bias=True)
#   (B2): Linear(in_features=64, out_features=64, bias=True)
#   (outputB): Linear(in_features=64, out_features=12, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Total parameters: 19608

# %%
# Runge-Kutta 4th order method for ODE solving
def rk4_step_func(func, x0, u, dt):
    k1 = func(x0, u)
    k1 = k1*dt

    k2 = func(x0+k1/2, u)
    k2 = k2*dt

    k3 = func(x0+k2/2, u)
    k3 = k3*dt

    k4 = func(x0+k3, u)
    k4 = k4*dt

    return x0 + (k1 + 2 * (k2 + k3) + k4) / 6

# %%
# One step training
import torch.optim as optim
from torcheval.metrics.functional import mean_squared_error, r2_score
from scipy.integrate import odeint

def one_step_training_rk4(model, criterion, optimizer, x, u, dt):
    t = 0
    loss = 0.0
    model.train()
    with torch.set_grad_enabled(True):
        # Forward pass
        pred = rk4_step_func(model, x[:-1], u[:-1], dt)  # Integrate over a small time step
        loss = criterion(pred, x[1:])
        # Backward and optimize
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    r2 = r2_score(pred, x[1:])
    return pred, loss, r2

# %%
# Load trained model weights
model.load_state_dict(torch.load('./rigid_body_nn_model_clean_input.pth'))
# Out:
# <All keys matched successfully>

# %%
# MODEL STRUCTURE

import torch
import torch.nn as nn
import torch.nn.functional as F
n_neurons = 32
dropout_rate = 0.5
class RigidBodyNNv2(nn.Module):
    def __init__(self, u_size=1, x_size=3):  
        super(RigidBodyNNv2, self).__init__()
        # Fully connected layers
        self.A1 = nn.Linear(x_size, n_neurons) 
        self.A2 = nn.Linear(n_neurons, n_neurons)
        self.A3 = nn.Linear(n_neurons, n_neurons)
        self.A4 = nn.Linear(n_neurons, n_neurons)
        self.outputA = nn.Linear(n_neurons, x_size)

        self.B1 = nn.Linear(u_size, n_neurons) 
        self.B2 = nn.Linear(n_neurons, n_neurons)
        self.B3 = nn.Linear(n_neurons, n_neurons)
        self.B4 = nn.Linear(n_neurons, n_neurons)
        self.outputB = nn.Linear(n_neurons, x_size)
        
        self.dropout = nn.Dropout(dropout_rate)
        

    def forward(self, x0, u):
        
        outA = F.softplus(self.A1(x0))
        outA = self.dropout(F.softplus(self.A2(outA)))
        outA = self.dropout(F.softplus(self.A3(outA)))
        outA = self.dropout(F.softplus(self.A4(outA)))
        outA = self.outputA(outA)

        outB = F.softplus(self.B1(u))
        outB = self.dropout(F.softplus(self.B2(outB)))
        outB = self.dropout(F.softplus(self.B3(outB)))
        outB = self.dropout(F.softplus(self.B4(outB)))
        outB = self.outputB(outB)

        x = outA + outB  
        return x

# Create the model
model = RigidBodyNNv2(u_size=u_train_dataset.shape[1], x_size=x_train_dataset.shape[1])

# Print model summary
print(model)
print(f'Total parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}')
# Out:
# RigidBodyNNv2(
#   (A1): Linear(in_features=12, out_features=32, bias=True)
#   (A2): Linear(in_features=32, out_features=32, bias=True)
#   (A3): Linear(in_features=32, out_features=32, bias=True)
#   (A4): Linear(in_features=32, out_features=32, bias=True)
#   (outputA): Linear(in_features=32, out_features=12, bias=True)
#   (B1): Linear(in_features=8, out_features=32, bias=True)
#   (B2): Linear(in_features=32, out_features=32, bias=True)
#   (B3): Linear(in_features=32, out_features=32, bias=True)
#   (B4): Linear(in_features=32, out_features=32, bias=True)
#   (outputB): Linear(in_features=32, out_features=12, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
# Total parameters: 7832

# %%
# Compare three models
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#model1 = RigidBodyNN(u_size=u_train_dataset.shape[1], x_size=x_train_dataset.shape[1], n_neurons=64).to(device)
model2 = RigidBodyNNv2(u_size=u_train_dataset.shape[1], x_size=x_train_dataset.shape[1]).to(device)
model3 = RigidBodyNN(u_size=u_train_dataset.shape[1], x_size=x_train_dataset.shape[1], n_neurons=64).to(device)
#  Load trained model weights
#model1.load_state_dict(torch.load('./rigid_body_nn_model_clean_input.pth'))
model2.load_state_dict(torch.load('./rigid_body_nn_model_v2_clean.pth'))
model3.load_state_dict(torch.load('./rigid_body_nn_model_clean_input_1.pth'))

# Simulation
# Out:
# <All keys matched successfully>

# %%
# Simulation
from torcheval.metrics.functional import r2_score, mean_squared_error
def simulate_model(model, x_test_tensor, u_test_tensor, dt):
    model.eval()
    with torch.no_grad():
        sim_size = x_test_tensor.shape[0]
        input_sim = x_test_tensor[0, :]
        x_sim_history = torch.zeros((sim_size, 12),device=device)
        for i in range(sim_size - 1):
            x_sim = rk4_step_func(model, input_sim,
                                   u_test_tensor[i, :], dt)
            input_sim = x_sim
            x_sim_history[i] = x_sim
    mse = mean_squared_error(x_sim_history[:-1], x_test_tensor[:-1])
    r2 = r2_score(x_sim_history[:-1], x_test_tensor[:-1], multioutput='raw_values')
    # remove infinite values from r2
    r2 = r2[~torch.isinf(r2)].mean()
    print(f"Model: {model.__class__.__name__}, MSE: {mse:.4f}, R2: {r2}")
    return x_sim_history

# %%
# Simulate and evaluate each model
dt = 5e-3
#x_sim_history1 = simulate_model(model1, x_test_tensor, u_test_tensor, dt)
x_sim_history2 = simulate_model(model2, x_test_tensor, u_test_tensor, dt)
x_sim_history3 = simulate_model(model3, x_test_tensor, u_test_tensor, dt)
# Out:
# Model: RigidBodyNNv2, MSE: 0.0180, R2: -4.095308780670166
# Model: RigidBodyNN, MSE: 0.0030, R2: 0.29628419876098633

# %%
# Compare predictions

import matplotlib.pyplot as plt
x_labels = ['u', 'v', 'w', 'p', 'q', 'r', 'xe', 'ye', 'ze', 'roll', 'pitch', 'yaw']
plt.figure(figsize=(12, 18))
for i in range(x_test_tensor.shape[1]):
    plt.subplot(6, 2, i+1)
    plt.plot(x_test_tensor[:-1, i].cpu().detach().numpy(), label='True')

    #plt.plot(x_sim_history1[:-1, i].cpu().detach().numpy(), linestyle='--', label='Model 1 Predicted')
    plt.plot(x_sim_history2[:-1, i].cpu().detach().numpy(), linestyle='--', label='Model A Predicted')
    plt.plot(x_sim_history3[:-1, i].cpu().detach().numpy(), linestyle='--', label='Model B Predicted')
    plt.xlabel('Sample')
    plt.ylabel(f'{x_labels[i]}')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# save the scalers
import joblib
joblib.dump(x_scaler, 'x_scaler.save')
joblib.dump(u_scaler, 'u_scaler.save')
# Out:
# ['u_scaler.save']
